# %%
import datetime as dt
import pandas as pd

from fmiopendata.wfs import download_stored_query

# %% [markdown]
# Vähennetään end_time ajasta 3 tuntia, koska datan viemisessä internettiin kestää hetken ja näin vältytään tyhjiltä (NaN) arvoilta

# %%
# Retrieve the latest hour of data from a bounding box
end_time = dt.datetime.now() - dt.timedelta(hours=3)
start_time = end_time - dt.timedelta(days=7)
# Convert times to properly formatted strings
start_time = start_time.isoformat(timespec="seconds") + "Z"
# -> 2025-09-28T12:00:00Z
end_time = end_time.isoformat(timespec="seconds") + "Z"
# -> 2025-09-28T13:00:00Z

# %% [markdown]
# Katsotaan minkälaisia mittauspisteitä määrittelemälläni alueelta löytyy. Tämän perusteella valitaan Tampereen ja Helsingin keskustojen läheisyydessä sijaitsevat mittauspisteet.

# %%
obs = download_stored_query("urban::observations::airquality::hourly::multipointcoverage", # ILMANLAATUPARAMETRI
                            args=["bbox=23,60,26,63",
                                  "starttime=" + start_time,
                                  "endtime=" + end_time])

df
# Out:
#                 datetime                         location  Sulphur dioxide  \
# 0    2025-09-26 14:00:00                Helsinki Kallio 2              0.7
# 1    2025-09-26 14:00:00  Espoo Leppävaara Läkkisepänkuja              NaN
# 2    2025-09-26 14:00:00                     Espoo Luukki             -0.4
# 3    2025-09-26 14:00:00         Helsinki Mannerheimintie              NaN
# 4    2025-09-26 14:00:00     Vantaa Tikkurila Neilikkatie              NaN
# ...                  ...                              ...              ...
# 1387 2025-09-28 13:00:00                 Hollola Kuntotie              NaN
# 1388 2025-09-28 13:00:00          Helsinki Teollisuuskatu              NaN
# 1389 2025-09-28 13:00:00              Helsinki Tapanila 2              NaN
# 1390 2025-09-28 13:00:00       Vantaa Kehä III Viinikkala              NaN
# 1391 2025-09-28 13:00:00       Helsinki Kustaa Vaasan tie              NaN
#
#       Nitrogen monoxide  Nitrogen dioxide  Ozone  Odorous sulphur compounds  \
# 0                   0.5               4.6   56.4                        NaN
# 1                   1.4               5.3    NaN                        NaN
# 2                  -0.1               0.8   56.2                        NaN
# 3                  10.7              16.2    NaN                        NaN
# 4                   0.9               5.1    NaN                        NaN
# ...                 ...               ...    ...                        ...
# 1387                NaN               2.2    NaN                        NaN
# 1388                1.2               4.0   54.8                        NaN
# 1389                NaN               NaN    NaN                        NaN
# 1390                2.0               8.0    NaN                        NaN
# 1391                1.3               2.6    NaN                        NaN
#
#       Carbon monoxide  Particulate matter < 10 µm  \
# 0                 NaN                         4.8
# 1                 NaN                         5.1
# 2                 NaN                         3.9
# 3                 NaN                        10.4
# 4                 NaN                         5.5
# ...               ...                         ...
# 1387              NaN                         5.1
# 1388              NaN                         4.1
# 1389              NaN                         NaN
# 1390              NaN                         4.0
# 1391              NaN                         3.2
#
#       Particulate matter < 2.5 µm  Air Quality Index  musta hiili PM2.5
# 0                             1.6                1.0               0.11
# 1                             1.6                1.0               0.20
# 2                             1.3                1.0               0.05
# 3                             3.1                1.0               0.30
# 4                             1.6                1.0                NaN
# ...                           ...                ...                ...
# 1387                          2.0                1.0                NaN
# 1388                          1.3                1.0               0.10
# 1389                          NaN                NaN               0.09
# 1390                          1.6                1.0                NaN
# 1391                          1.2                1.0                NaN
#
# [1392 rows x 12 columns]

# %% [markdown]
# Tarkistetaan, että datan tyypitykset ovat oikein jatkokäsittelyä varten.
# Tässä esimerkissä datatyypit ovat datetime64[ns], object ja float64.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1392 entries, 0 to 1391
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   datetime                     1392 non-null   datetime64[ns]
#  1   location                     1392 non-null   object
#  2   Sulphur dioxide              288 non-null    float64
#  3   Nitrogen monoxide            624 non-null    float64
#  4   Nitrogen dioxide             1248 non-null   float64
#  5   Ozone                        384 non-null    float64
#  6   Odorous sulphur compounds    48 non-null     float64
#  7   Carbon monoxide              0 non-null      float64
#  8   Particulate matter < 10 µm   1152 non-null   float64
#  9   Particulate matter < 2.5 µm  1152 non-null   float64
#  10  Air Quality Index            1344 non-null   float64
#  11  musta hiili PM2.5            336 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 130.6+ KB

# %% [markdown]
# Valitaan mittauspisteiksi:
# * Tampere Linja-autoasema
# * Helsinki Mannerheimintie
#
# Valitaan mittausdatasta tarkasteltavaksi:
# * datetime
# * location
# * Particular matter < 2.5 µm
# * Air Quality Index
# * Nitrogen dioxide

# %%
records = []

for datet, locations in obs.data.items():
    for location, pollutants in locations.items():
        record = {'datetime': datet, 'location': location}
        for pollutant, values in pollutants.items():
            record[pollutant] = values['value']
        records.append(record)

df = pd.DataFrame(records)

filtered_df = df[df['location'].isin(['Tampere Linja-autoasema','Helsinki Mannerheimintie'])][['datetime','location', 'Particulate matter < 2.5 µm','Air Quality Index', 'Nitrogen dioxide']]

filtered_df
# Out:
#                 datetime                  location  \
# 3    2025-09-21 16:00:00  Helsinki Mannerheimintie
# 9    2025-09-21 16:00:00   Tampere Linja-autoasema
# 32   2025-09-21 17:00:00  Helsinki Mannerheimintie
# 38   2025-09-21 17:00:00   Tampere Linja-autoasema
# 61   2025-09-21 18:00:00  Helsinki Mannerheimintie
# ...                  ...                       ...
# 4794 2025-09-28 13:00:00   Tampere Linja-autoasema
# 4817 2025-09-28 14:00:00  Helsinki Mannerheimintie
# 4823 2025-09-28 14:00:00   Tampere Linja-autoasema
# 4846 2025-09-28 15:00:00  Helsinki Mannerheimintie
# 4852 2025-09-28 15:00:00   Tampere Linja-autoasema
#
#       Particulate matter < 2.5 µm  Air Quality Index  Nitrogen dioxide
# 3                             9.3                1.0              18.6
# 9                             5.2                1.0              11.6
# 32                            9.9                1.0              11.6
# 38                            4.5                1.0               7.4
# 61                           10.4                2.0               6.4
# ...                           ...                ...               ...
# 4794                          0.3                1.0               5.9
# 4817                          3.4                1.0               8.2
# 4823                          1.6                1.0               8.3
# 4846                          3.4                1.0               8.6
# 4852                          2.1                1.0               7.1
#
# [336 rows x 5 columns]

# %% [markdown]
# Tallenetaan datataulu CSV-muotoon, jota voimme käyttää pohjana Power BI -raportille. Tallenetaan datataulu suoraan /data/processed/ -kansioon.

# %%
filtered_df.to_csv("/users/raunopaukkeri/Kaisuhamk/bi_project/data/processed/ilmanlaatu_tampere_helsinki.csv", index=False)

# %%
filtered_df.head()
# Out:
#               datetime                  location  Particulate matter < 2.5 µm  \
# 3  2025-09-21 16:00:00  Helsinki Mannerheimintie                          9.3
# 9  2025-09-21 16:00:00   Tampere Linja-autoasema                          5.2
# 32 2025-09-21 17:00:00  Helsinki Mannerheimintie                          9.9
# 38 2025-09-21 17:00:00   Tampere Linja-autoasema                          4.5
# 61 2025-09-21 18:00:00  Helsinki Mannerheimintie                         10.4
#
#     Air Quality Index  Nitrogen dioxide
# 3                 1.0              18.6
# 9                 1.0              11.6
# 32                1.0              11.6
# 38                1.0               7.4
# 61                2.0               6.4
